# %%
import random 

row=int(input("Enter row : "))  # row enter 
col=int(input("Enter col : "))  # column enter 

# matrx=[ random.choices(lst,k=row) for i in range(col) for j in range(row)]
matrx=[ [int(input()) for i in range(col)]for j in range(row)]

for i in range(row):
  for j in range(col):
    print(format(matrx[i][j],"<3"),end="")
  print()


matrx1=[[int(input()) for i in range(col)] for j in range(row)]

adn=[[matrx[k][j]+matrx1[k][j] for i in range(col)] for j in range(row)]

print(adn)


for i in range(row):
  for j in range(col):
    print(format(matrx1[i][j],"<3"),end="")
  print()3

# Addition  

for k in range(row):
  for j in range(col):
    print(format(matrx[k][j]+matrx1[k][j],"<3"),end="")
  print()
# Out:
# Enter row : 2
# Enter col : 2
# 12
# 34
# 12
# 34
# 12 34
# 12 34
# 12
# 3
# 4
# 3
# [[16, 16], [37, 37]]
# 12 3
# 4  3
# 24 37
# 16 37
